# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
nm = ['Kopiko','Torabika','Bengbeng','Choki-choki','Teh Pucuk','Energen']
stk = [52,39,78,13,78,29]
databarang = {'names':nm,'stok':stk}

print(databarang)
# Out:
# {'names': ['Kopiko', 'Torabika', 'Bengbeng', 'Choki-choki', 'Teh Pucuk', 'Energen'], 'stok': [52, 39, 78, 13, 78, 29]}

# %%
dt = pd.DataFrame(data=databarang, columns=['names','stok']);

print(dt)
# Out:
#          names  stok
# 0       Kopiko    52
# 1     Torabika    39
# 2     Bengbeng    78
# 3  Choki-choki    13
# 4    Teh Pucuk    78
# 5      Energen    29

# %%
dt.groupby(['names']).sum().plot(kind='pie', y='stok', autopct='%1.0f%%')
# Out:
# <AxesSubplot: ylabel='stok'>
